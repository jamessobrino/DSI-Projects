# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
lst= [1,2,3,4,5]

def mean(lst):
    return sum(lst)/ len(lst)

print(mean(lst))
# Out:
# 3.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
lst = [1,2,3,4,5]

def standard_dev(lst):
    mean_lst = mean(lst)
    sd_acc = 0
    
    for num in lst:
        sd_acc += (num - mean_lst)**2
    return (sd_acc / len(lst))**.5
        
standard_dev(lst)
# Out:
# 1.4142135623730951

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:

def data_clean(string):
    if type(string) == str:
        if "%" in string:
            if string.replace("%", "").isnumeric():
                return float(string.replace("%", ""))/100
    elif type(string) != str:
        return string
print(data_clean("65%"))
print(data_clean(25))
# Out:
# 0.65
# 25

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ![Screen Shot 2021-09-09 at 9.05.58 PM.png](attachment:3f44fc9a-9296-4fda-a8bf-3475495c15a5.png)### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Code:
sat = pd.read_csv('../data/sat_2019.csv')
act = pd.read_csv('../data/act_2019.csv')
census = pd.read_csv('../data/pupil_census.csv')
#census data is per pupil spending in dollars

# %% [markdown]
# ### 1

# %%
sat.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
act.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
census.head()
# Out:
#         State  Total  employee wages employee benefits Instruction Total  \
# 0     Alabama  10,077          5,632             2,249             5,715
# 1      Alaska  18,394          8,675             5,105             9,789
# 2     Arizona   8,625          5,157             1,674             4,705
# 3    Arkansas  10,388          6,036             1,712             5,842
# 4  California  14,035          7,804             4,066             8,374
#
#   Instruction wages instruction benefits support Total pupil support  \
# 0             3,637                1,395         3,688           658
# 1             5,549                3,194         7,937         1,425
# 2             3,225                1,022         3,470           721
# 3             3,876                1,101         3,985           577
# 4             4,917                2,546         5,130           901
#
#   instructional staffsupport general administration school administration
# ...

# %% [markdown]
# ### 2

# %%
#ACT has no missing values
act.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
# - does not count as a null value
sat.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
sat["Participation Rate"].sort_values(ascending = False)
#participation for rows 47 and 39 are missing
# Out:
# 47       —
# 39       —
# 50     99%
# 19     99%
# 29     95%
# 8      94%
# 26      9%
# 20     82%
# 30     82%
# 21     81%
# 32     79%
# 10     71%
# 38     70%
# 49     70%
# 0       7%
# 43      7%
# 48     68%
# 41     68%
# 44     68%
# 46     66%
# 14     66%
# 4      63%
# 3       6%
# 11     54%
# 37     51%
# 33     51%
# 18      5%
# 1      41%
# 25      4%
# 23      4%
# 45      4%
# 17      4%
# 16      4%
# 2      31%
# 15      3%
# 42      3%
# 24      3%
# 52      3%
# 27      3%
# 51      3%
# 36     22%
# 28     20%
# 34      2%
# 35     19%
# 31     18%
# 13    100%
# 9     100%
# 40    100%
# 7     100%
# 6     100%
# 5     100%
# 22    100%
# 12    100%
# Name: Participation Rate, dtype: object

# %% [markdown]
# ### 3

# %%
#Within realisitc bounds of an average score
act["Composite"].max()
act["Composite"].min()
# Out:
# 17.9

# %%
#range of scores Max = 800, Min = 200
sat["EBRW"].max()
sat["EBRW"].min()
sat["Math"].max()
sat["Math"].min()
sat["Total"].max()
sat["Total"].min()
#all within bounds of possible values
# Out:
# 935

# %% [markdown]
# ### 4

# %%
#not sure what im supposed to do here? the only errors in data i found are
# - for some of the participation rates. Are 100% participation rates also wrong?

#sat.replace({"—": np.nan})

# %% [markdown]
# ### 5

# %%
sat.dtypes
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %%
act.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
census.dtypes
# Out:
# State                         object
# Total                         object
# employee wages                object
# employee benefits             object
# Instruction Total             object
# Instruction wages             object
# instruction benefits          object
# support Total                 object
# pupil support                 object
# instructional staffsupport    object
# general administration        object
# school administration         object
# dtype: object

# %% [markdown]
# ### 6

# %%
act["Participation"] = act['Participation'].map(data_clean)

# %%
sat["Participation Rate"] = sat['Participation Rate'].map(data_clean)

# %%
sat.dropna(inplace = True)

# %%
#function for converting values in census data

def census_convert(string):
    if type(string) == str:
        if "," in string:
            if string.replace(",", "").isnumeric():
                return float(string.replace(",", ""))
        elif type(string) == str:
            if str.isnumeric:
                return int(string)
    else:
        return string
#Had to convert each column to a float manually because my dictionary comprehension wasnt working.

# %%
census["Total "] = census["Total "].map(census_convert)

# %%
census["employee wages"] = census["employee wages"].map(census_convert)

# %%
census["employee benefits"] = census["employee benefits"].map(census_convert)

# %%
census["Instruction Total"] = census["Instruction Total"].map(census_convert)

# %%
census["Instruction wages"] = census["Instruction wages"].map(census_convert)

# %%
census["instruction benefits"] = census["instruction benefits"].map(census_convert)

# %%
census["support Total"] = census["support Total"].map(census_convert)

# %%
census["pupil support"] = census["pupil support"].map(census_convert)

# %%
census["instructional staffsupport"] = census["instructional staffsupport"].map(census_convert)

# %%
census["general administration"] = census["general administration"].map(census_convert)

# %%
census["school administration"] = census["school administration"].map(census_convert)

# %%
census
# Out:
#                    State   Total   employee wages  employee benefits  \
# 0                Alabama  10077.0          5632.0             2249.0
# 1                 Alaska  18394.0          8675.0             5105.0
# 2                Arizona   8625.0          5157.0             1674.0
# 3               Arkansas  10388.0          6036.0             1712.0
# 4             California  14035.0          7804.0             4066.0
# 5               Colorado  11030.0          6748.0             2341.0
# 6            Connecticut  21310.0         11595.0             6275.0
# 7               Delaware  16315.0          8664.0             4735.0
# 8   District of Columbia  22406.0         15361.0             3024.0
# 9                Florida   9645.0          5281.0             1708.0
# 10               Georgia  11228.0          6497.0             2755.0
# 11                Hawaii  16132.0          8350.0             4577.0
# 12                 Idaho   7985.0          4744.0             1709.0
# ...

# %% [markdown]
# ### 7

# %%
#renaming columns to lower case
census_columns_dict = {
    'Total ': 'total',
    'employee wages': 'emp_wages',
    'employee benefits': 'emp_benefits',
    'Instruction Total': 'instr_total',
    'Instruction wages': 'instr_wages',
    'instruction benefits': 'instr_benefits',
    'support Total': 'sup_total',
    'pupil support': 'pupil_sup',
    'instructional staffsupport': 'staff_sup',
    'general administration': 'gen_admin',
    'school administration': 'school_admin',
    'State' : 'state'
}


census.rename(columns = census_columns_dict, inplace = True)

# %%
act_columns_dict = {
    'Participation': 'act_participation',
    'Composite': 'act_composite',
    'State' : 'state'
}

# %%
act.rename(columns = act_columns_dict, inplace = True)

# %%
sat_columns_dict = {
    'Participation Rate': 'sat_participation',
    'EBRW' : 'english_sect', 
    'Math' : 'math_sect',
    'Total' : 'total_score',
    'State' : 'state'
}

sat.rename(columns = sat_columns_dict, inplace = True)

# %% [markdown]
# ### 8

# %%
#already completed this earlier while changing data types to circumvent errors

# %%
#dropping national data set so i can merge all 3 df
act.drop(axis= 0, index = 51, inplace = True)

# %% [markdown]
# ### 9

# %%
act.shape
# Out:
# (51, 3)

# %%
sat.shape
# Out:
# (51, 5)

# %%
census.shape
# Out:
# (51, 12)

# %%
sat.reset_index(inplace = True, drop = True)

# %%
#merging ACT and SAT data
df = pd.merge(sat, act, on='state', how='left')

# %%
#merging ACT/SAT data on Census Data
tests_w_census = pd.merge(df, census, on ='state', how = 'left')

# %%
tests_w_census.head()
# Out:
#         state  sat_participation  english_sect  math_sect  total_score  \
# 0     Alabama               0.07           583        560         1143
# 1      Alaska               0.41           556        541         1097
# 2     Arizona               0.31           569        565         1134
# 3    Arkansas               0.06           582        559         1141
# 4  California               0.63           534        531         1065
#
#    act_participation  act_composite    total  emp_wages  emp_benefits  \
# 0               1.00           18.9  10077.0     5632.0        2249.0
# 1               0.38           20.1  18394.0     8675.0        5105.0
# 2               0.73           19.0   8625.0     5157.0        1674.0
# 3               1.00           19.3  10388.0     6036.0        1712.0
# 4               0.23           22.6  14035.0     7804.0        4066.0
#
#    instr_total  instr_wages  instr_benefits  sup_total  pupil_sup  staff_sup  \
# ...

# %% [markdown]
# ### 10

# %%
#necessary cleaning has been done

# %% [markdown]
# ### 11

# %%
tests_w_census.to_csv('../data/tests_w_census.csv', index= False)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %%
#Data Dictionary

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|
# |state|object|All|This column labels each state for the dataframe.|
# |sat_participation|float|SAT|Participation data for SAT|
# |english_sect|int|SAT|Mean scores for the english section of SAT|
# |math_sect|int|SAT|Mean scores for the math section of SAT|
# |total_score|int|SAT|Mean scores for total score of math and english sections|
# |act_participation|float|ACT|Participation data for ACT|
# |act_composite|float|ACT|Mean score of ACT|
# |total|float|census|Total spending per pupil.|
# |emp_wages|float|census|Amounts paid for compensation of school system officers and employees. Consists of gross compensation before deductions for withheld taxes, retirement contributions, or other purposes per pupil|
# |emp_benefits|float|census|Total spending on employee benefits per pupil|
# |instr_total|float|census|Total spending on instructors per pupil|
# |instr_wages|float|census|Total Spending on instructor wages per pupil|
# |instr_benefits|float|census|Total spending on instructor benefits|
# |sup_total|float|census|Total spending on support services per pupil|
# |pupil_sup|float|census|Expenditure for attendance record-keeping, social work, student accounting, counseling, student appraisal, record maintenance, and placement services. This category also includes medical, dental, nursing, psychological, and speech services.|
# |staff_sup|float|census|recruitment, staff accounting, noninstructional in-service training, staff health services|
# |gen_admin|float|census|Expenditure for board of education and executive administration (office of the superintendent) services|
# |school_admin|float|census|Expenditure for the office of principal services|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Code:
tests_w_census.describe
# Out:
# <bound method NDFrame.describe of                    state  sat_participation  english_sect  math_sect  \
# 0                Alabama               0.07           583        560
# 1                 Alaska               0.41           556        541
# 2                Arizona               0.31           569        565
# 3               Arkansas               0.06           582        559
# 4             California               0.63           534        531
# 5               Colorado               1.00           518        506
# 6            Connecticut               1.00           529        516
# 7               Delaware               1.00           499        486
# 8   District of Columbia               0.94           495        480
# 9                Florida               1.00           516        483
# 10               Georgia               0.71           538        519
# 11                Hawaii               0.54           550        550
# ...

# %%
#dict comprehension for std function

sd = {tests_w_census[k]: standard_dev(v) for k, v in tests_w_census.items() if tests_w_census[k][0] == float}
sd
#### not sure why this doesnt work, tried to exclude state column by calling if not df"state", tried excluding str, tried only passing float and int values
# Out:
# {}

# %%
d = {}
for k, v in d.items():
    d[tests_w_census[k]] = standard_dev(tests_w_census[k])
d
#this doesnt work either... I'm not sure what im doing wrong
# Out:
# {}

# %%
print(standard_dev(tests_w_census["total_score"]))
print(standard_dev(tests_w_census["act_composite"]))
print(standard_dev(tests_w_census["pupil_sup"]))
print(standard_dev(tests_w_census["instr_total"]))
print(standard_dev(tests_w_census["gen_admin"]))
print(standard_dev(tests_w_census["school_admin"]))
# Out:
# 96.24027185617864
# 2.172901153595978
# 469.88013392114016
# 2441.6785377086626
# 220.96499241711263
# 246.34576058103295

# %%
tests_w_census["pupil_sup"].sort_values(ascending= True).head()
#I want to look at 44, 23, 9, 12, 42 initially all spend less than $500 on pupil sup
# Out:
# 44    366.0
# 23    414.0
# 9     445.0
# 12    475.0
# 42    494.0
# Name: pupil_sup, dtype: float64

# %%
tests_w_census["pupil_sup"].sort_values(ascending= False).head()
# 30, 8, 39, 45, 11
# Out:
# 30    2396.0
# 8     2319.0
# 39    1969.0
# 45    1861.0
# 11    1695.0
# Name: pupil_sup, dtype: float64

# %%
tests_w_census["total_score"].sort_values(ascending= True).head()
#48, 36, 8, 7, 12
# Out:
# 48    943
# 36    963
# 8     975
# 7     985
# 12    993
# Name: total_score, dtype: int64

# %%
tests_w_census["total_score"].sort_values(ascending= False).head()
#23, 49, 41, 23, 27
# Out:
# 23    1284
# 49    1283
# 41    1268
# 34    1263
# 27    1260
# Name: total_score, dtype: int64

# %%
tests_w_census["act_composite"].sort_values(ascending= True).head()
#28, 24, 40, 18, 0
# Out:
# 28    17.9
# 24    18.4
# 40    18.8
# 18    18.8
# 0     18.9
# Name: act_composite, dtype: float64

# %%
tests_w_census["act_composite"].sort_values(ascending= False).head()
#21, 6, 29, 39, 32
# Out:
# 21    25.5
# 6     25.5
# 29    25.0
# 39    24.7
# 32    24.5
# Name: act_composite, dtype: float64

# %%
tests_w_census["gen_admin"].sort_values(ascending= True).head()
# 11, 9, 44, 40, 33
# Out:
# 11     67.0
# 9      86.0
# 44     87.0
# 40     98.0
# 33    106.0
# Name: gen_admin, dtype: float64

# %%
tests_w_census["gen_admin"].sort_values(ascending= False).head()
#8, 29, 13, 25, 34
# Out:
# 8     1452.0
# 29     635.0
# 13     631.0
# 25     606.0
# 34     600.0
# Name: gen_admin, dtype: float64

# %%
tests_w_census["school_admin"].sort_values(ascending= False).head()
#8,45, 6, 11, 32
# Out:
# 8     1572.0
# 45    1519.0
# 6     1242.0
# 11    1149.0
# 32    1133.0
# Name: school_admin, dtype: float64

# %%
tests_w_census["school_admin"].sort_values(ascending= True).head()
#2, 12, 41, 44, 9
# Out:
# 2     403.0
# 12    461.0
# 41    502.0
# 44    514.0
# 9     521.0
# Name: school_admin, dtype: float64

# %%
tests_w_census["total"].sort_values(ascending= False).head()
# Out:
# 32    25139.0
# 8     22406.0
# 6     21310.0
# 30    20512.0
# 45    20315.0
# Name: total, dtype: float64

# %%
tests_w_census["total"].sort_values(ascending= True).head()
# Out:
# 12    7985.0
# 44    8014.0
# 2     8625.0
# 24    9284.0
# 36    9323.0
# Name: total, dtype: float64

# %%
tests_w_census
# Out:
#                    state  sat_participation  english_sect  math_sect  \
# 0                Alabama               0.07           583        560
# 1                 Alaska               0.41           556        541
# 2                Arizona               0.31           569        565
# 3               Arkansas               0.06           582        559
# 4             California               0.63           534        531
# 5               Colorado               1.00           518        506
# 6            Connecticut               1.00           529        516
# 7               Delaware               1.00           499        486
# 8   District of Columbia               0.94           495        480
# 9                Florida               1.00           516        483
# 10               Georgia               0.71           538        519
# 11                Hawaii               0.54           550        550
# 12                 Idaho               1.00           505        488
# ...

# %%
tests_w_census["total_score"].mean()
# Out:
# 1113.078431372549

# %%
# states where total spending per pupil is higher than the mean and act scores are lower than the mean.
tests_w_census.loc[(tests_w_census["total"] > tests_w_census["total"].mean()) & (tests_w_census["act_composite"] < 19.29)]
# Out:
#      state  sat_participation  english_sect  math_sect  total_score  \
# 11  Hawaii               0.54           550        550         1100
#
#     act_participation  act_composite    total  emp_wages  emp_benefits  \
# 11                0.8           19.0  16132.0     8350.0        4577.0
#
#     instr_total  instr_wages  instr_benefits  sup_total  pupil_sup  staff_sup  \
# 11       9378.0       5639.0          3009.0     5955.0     1695.0      513.0
#
#     gen_admin  school_admin
# 11       67.0        1149.0

# %%
tests_w_census.loc[ (tests_w_census["act_composite"] < 19.29)]
# the only states with a mean score below 1 standard deviation have a participation rate above 70%
# Arizona, Hawaii, and South Carolina were the only states that did not have 100% participation rate that scored this low
# Out:
#              state  sat_participation  english_sect  math_sect  total_score  \
# 0          Alabama               0.07           583        560         1143
# 2          Arizona               0.31           569        565         1134
# 11          Hawaii               0.54           550        550         1100
# 18       Louisiana               0.05           610        591         1200
# 24     Mississippi               0.03           628        608         1237
# 28          Nevada               0.20           580        576         1156
# 33  North Carolina               0.51           554        546         1100
# 36        Oklahoma               0.22           490        472          963
# 40  South Carolina               0.68           526        504         1030
#
#     act_participation  act_composite    total  emp_wages  emp_benefits  \
# 0                1.00           18.9  10077.0     5632.0        2249.0
# ...

# %%
print(mean(tests_w_census["act_composite"]))
print(mean(tests_w_census["act_composite"]) - standard_dev(tests_w_census["act_composite"]))
# Out:
# 21.464705882352934
# 19.291804728756958

# %%
#15 lowest spending states per pupil
state_spend = tests_w_census.sort_values(by = 'total', ascending = True)[:15]
state_spend
# Out:
#              state  sat_participation  english_sect  math_sect  total_score  \
# 12           Idaho               1.00           505        488          993
# 44            Utah               0.04           614        615         1230
# 2          Arizona               0.31           569        565         1134
# 24     Mississippi               0.03           628        608         1237
# 36        Oklahoma               0.22           490        472          963
# 28          Nevada               0.20           580        576         1156
# 9          Florida               1.00           516        483          999
# 43           Texas               0.68           515        507         1022
# 33  North Carolina               0.51           554        546         1100
# 42       Tennessee               0.07           618        602         1220
# 0          Alabama               0.07           583        560         1143
# ...

# %%
bad_outcomes = tests_w_census.loc[(tests_w_census["total_score"] < tests_w_census["total_score"].mean()) & (tests_w_census["act_composite"] < tests_w_census["act_composite"].mean())]
bad_outcomes
#these states scored below the mean on both tests
# Out:
#              state  sat_participation  english_sect  math_sect  total_score  \
# 1           Alaska               0.41           556        541         1097
# 9          Florida               1.00           516        483          999
# 10         Georgia               0.71           538        519         1058
# 11          Hawaii               0.54           550        550         1100
# 31      New Mexico               0.18           543        530         1073
# 33  North Carolina               0.51           554        546         1100
# 35            Ohio               0.19           550        548         1097
# 36        Oklahoma               0.22           490        472          963
# 37          Oregon               0.51           562        550         1112
# 40  South Carolina               0.68           526        504         1030
# 43           Texas               0.68           515        507         1022
# ...

# %%
good_outcomes = tests_w_census.loc[(tests_w_census["total_score"] > tests_w_census["total_score"].mean()) & (tests_w_census["act_composite"] > tests_w_census["act_composite"].mean())]
good_outcomes
#These states scored above the mean on both tests
# Out:
#             state  sat_participation  english_sect  math_sect  total_score  \
# 15           Iowa               0.03           622        622         1244
# 21  Massachusetts               0.81           559        561         1120
# 41   South Dakota               0.03           633        635         1268
# 46       Virginia               0.68           567        551         1119
#
#     act_participation  act_composite    total  emp_wages  emp_benefits  \
# 15               0.66           21.6  11907.0     7550.0        2564.0
# 21               0.21           25.5  17748.0    11069.0        4495.0
# 41               0.75           21.6  10139.0     6132.0        1780.0
# 46               0.21           24.0  12641.0     7769.0        3208.0
#
#     instr_total  instr_wages  instr_benefits  sup_total  pupil_sup  staff_sup  \
# 15       7148.0       4994.0          1678.0     4271.0      716.0      755.0
# ...

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#Base code of visualizations were taken from lesson 2.01

# %%
sns.boxplot(data = tests_w_census['total_score']).set_title("State SAT Mean scores");
#quick box plot of distribution of SAT scores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ab98f319ade5> in <module>
# ----> 1 sns.boxplot(data = tests_w_census['total_score']).set_title("State SAT Mean scores");
#       2 #quick box plot of distribution of SAT scores
#
# NameError: name 'sns' is not defined

# %%
sns.boxplot(data = tests_w_census['act_composite']).set_title("State ACT Mean Scores");
#quick box plot of distribution of ACT scores

# %%
sns.boxplot(data = tests_w_census['total']).set_title('Distribution of State spending per pupil');
#quick box plot of distribution of total spending per pupil scores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b6571fb484b1> in <module>
# ----> 1 sns.boxplot(data = tests_w_census['total']).set_title('Distribution of State spending per pupil');
#       2 #quick box plot of distribution of total spending per pupil scores
#
# NameError: name 'sns' is not defined

# %%
#if you read this, I spent so much time trying to make my cenus data work, this heat map destroyed me because
#there were no significant correlations with any of the data I uploaded and I spent a too long trying to find
#anything interesting
plt.figure(figsize = (16,9))

corr = tests_w_census.corr()

mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr, mask = mask, square = True, cmap = 'mako', annot = True);

# %%
sat_part = tests_w_census.sort_values(by = 'sat_participation', ascending = False)[:15]
sat_score = tests_w_census.sort_values(by = 'total_score', ascending = True)[:15]

#create a color map for the chart
colors = []
for ele in sat_score["state"]:
    if ele in sat_part.values:
        colors.append("darkcyan")
    else:
        colors.append("khaki")
        
plt.figure(figsize = (15, 5))



 # Bar chart
plt.bar(sat_score['state'],
    sat_score['total_score'],
        color=colors)
       

# Axis labels and titles
plt.title('Lowest 15 State SAT Mean Scores')
# Rotate text
plt.xticks(rotation = 90)
# Add axis labels
plt.xlabel('States')
plt.ylabel('SAT Score');
plt.ylim(900, 1075)

#https://stackoverflow.com/questions/57340415/matplotlib-bar-plot-add-legend-from-categories-dataframe-column
#created a legend for the chart
legend = {'States in Top 15 SAT Participation':'darkcyan', 'States not in Top 15 SAT Participation':'khaki'}         
labels = list(legend.keys())
handles = [plt.Rectangle((0,0),1,1, color=legend[label]) for label in labels]
plt.legend(handles, labels);

# %%
act_score = tests_w_census.sort_values(by = 'act_composite', ascending = True)[:15]
act_part = tests_w_census.sort_values(by = 'act_participation', ascending = False)[:15]

colors = []
for ele in act_score["state"]:
    if ele in act_part.values:
        colors.append("darkcyan")
    else:
        colors.append("khaki")
        
plt.figure(figsize = (15, 5))



        # Bar chart
plt.bar(act_score['state'],
    act_score['act_composite'],
        color=colors)
       

# Create a descriptive title
plt.title('Lowest 15 State ACT Mean Scores')
# Rotate text
plt.xticks(rotation = 90)
# Add axis labels
plt.xlabel('States')
plt.ylabel('ACT Score');
plt.ylim(17, 20)

#https://stackoverflow.com/questions/57340415/matplotlib-bar-plot-add-legend-from-categories-dataframe-column
#created a legend for the chart
legend = {'States in Top 15 ACT Participation':'darkcyan', 'States not in Top 15 ACT Participation':'khaki'}         
labels = list(legend.keys())
handles = [plt.Rectangle((0,0),1,1, color=legend[label]) for label in labels]
plt.legend(handles, labels);

# %%
state_spending = tests_w_census.sort_values(by = 'total', ascending = True)[:51]
plt.figure(figsize = (15, 5))

colors = []
for ele in state_spending["state"]:
    if ele in good_outcomes.values:
        colors.append("mediumorchid")
    elif ele in bad_outcomes.values:
        colors.append("khaki")
    else:
        colors.append("darkcyan")
        
# Bar chart
plt.bar(state_spending['state'],
    state_spending['total'],
       color = colors)
       

# Create a descriptive title
plt.title('State spending per pupil')
# Rotate text
plt.xticks(rotation = 90)
# Add axis labels
plt.xlabel('States')
plt.ylabel('Total Spending');


#https://stackoverflow.com/questions/57340415/matplotlib-bar-plot-add-legend-from-categories-dataframe-column
#created a legend for the chart
legend = {'SAT+ACT above mean':'mediumorchid', 'SAT+ACT below mean':'khaki', 'One above one below':'darkcyan' }         
labels = list(legend.keys())
handles = [plt.Rectangle((0,0),1,1, color=legend[label]) for label in labels]
plt.legend(handles, labels);

# %%
#ultimately decide to not use this graph but wanted to keep it for future reference on using plt.axvline

# %%
sat_part_score = tests_w_census.sort_values(by = 'total_score', ascending = True)[:51]

plt.figure(figsize = (15, 5))
        
# Bar chart
plt.bar(sat_part_score['state'],
    sat_part_score['sat_participation'])
       #color = colors)
       

# Axis labels and title
plt.title('State SAT participation ordered by SAT scores')
# Rotate text
plt.xticks(rotation = 90)
# Add axis labels
plt.xlabel('States')
plt.ylabel('SAT Participation');
#vertical line for the mean, used Ohio because it was 1 point under the mean. 
plt.axvline(x = tests_w_census['state'][37], color = 'orange');

# %%
# Size
plt.figure(figsize = (12, 5))

plt.scatter(tests_w_census['sat_participation'],
            tests_w_census['total_score'])

# Create a descriptive title
plt.title('Effect of SAT participation on SAT score')
# Add axis labels
plt.xlabel('SAT participation')
plt.ylabel('SAT score');

#https://www.statology.org/scatterplot-with-regression-line-python/
x = tests_w_census['sat_participation']
y = tests_w_census['total_score']
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x+b, color = "red");

# %%
# Size
plt.figure(figsize = (12, 5))

plt.scatter(tests_w_census['act_participation'],
            tests_w_census['act_composite'])

# Create a descriptive title
plt.title('Effect of ACT participation on ACT score')
# Add axis labels
plt.xlabel('ACT participation')
plt.ylabel('ACT score');

https://www.statology.org/scatterplot-with-regression-line-python/
x = tests_w_census['act_participation']
y = tests_w_census['act_composite']
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x+b, color = "red");

# %% [markdown]
# States that have mandatory standardized testing, tend to have lower mean scores. I predict this is a result
# of the population of students taking the test being every student, instead of only students
# with college aspirations.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# The best predictor for state mean test scores was participation. States that had mandatory participation scored well below the average.
#
# I recommend for states with high participation rates as a result of using these tests as a measure for student success, investing into an high school exit exam like california could increase test scores.
#
# If your state is Oklahoma, you should audit your education system. While you spend very little on education, you are not producing the same results as a comparable state spender such as Utah. Your SAT test scores are shockingly low for a state with very low participation.
