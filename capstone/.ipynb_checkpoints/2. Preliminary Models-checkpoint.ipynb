# %% [markdown]
# ### Games include pre and post season

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GRU, LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor

from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('./data/player_game_data.csv')

# %%
df.drop(columns = ['MIN'], inplace = True)

# %%
df.head()
# Out:
#   GAME_DATE_EST   GAME_ID     TEAM_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2021-05-26  42000102  1610612755    1610612755       1610612764
# 1    2021-05-26  42000102  1610612755    1610612755       1610612764
# 2    2021-05-26  42000102  1610612755    1610612755       1610612764
# 3    2021-05-26  42000102  1610612755    1610612755       1610612764
# 4    2021-05-26  42000102  1610612755    1610612755       1610612764
#
#         PLAYER_NAME  SEASON   FGM   FGA  FG_PCT  ...  REB_home  PTS_away  \
# 0  Anthony Tolliver    2020   0.0   0.0   0.000  ...      45.0      95.0
# 1       Ben Simmons    2020  11.0  15.0   0.733  ...      45.0      95.0
# 2       Danny Green    2020   2.0   3.0   0.667  ...      45.0      95.0
# 3     Dwight Howard    2020   1.0   4.0   0.250  ...      45.0      95.0
# 4    Furkan Korkmaz    2020   4.0   6.0   0.667  ...      45.0      95.0
#
#    FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS  \
# 0        0.402        0.633         0.091      22.0      40.0               1
# 1        0.402        0.633         0.091      22.0      40.0               1
# 2        0.402        0.633         0.091      22.0      40.0               1
# 3        0.402        0.633         0.091      22.0      40.0               1
# 4        0.402        0.633         0.091      22.0      40.0               1
#
#    SECONDS  FTSY_PTS
# 0      104       0.0
# 1     1714      43.0
# 2     1304      12.0
# 3      957      10.5
# 4      942      12.0
#
# [5 rows x 41 columns]

# %%
df.columns
# Out:
# Index(['GAME_DATE_EST', 'GAME_ID', 'TEAM_ID', 'HOME_TEAM_ID',
#        'VISITOR_TEAM_ID', 'PLAYER_NAME', 'SEASON', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TNO', 'PF', 'PTS', 'PLUS_MINUS',
#        'PTS_home', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home',
#        'REB_home', 'PTS_away', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away',
#        'AST_away', 'REB_away', 'HOME_TEAM_WINS', 'SECONDS', 'FTSY_PTS'],
#       dtype='object')

# %%
df['GAME_DATE_EST'] = pd.to_datetime(df['GAME_DATE_EST'])

# %%
players = df[['PLAYER_NAME', 'SEASON', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TNO', 'PF', 'PTS', 'PLUS_MINUS', 'SECONDS', 'FTSY_PTS']]

# %%
players.fillna(0, inplace = True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
play_season = players.groupby(['PLAYER_NAME', 'SEASON'], as_index= False)

# %%
play_season.mean()
# Out:
#           PLAYER_NAME  SEASON       FGM        FGA    FG_PCT      FG3M  \
# 0          AJ Hammons    2016  0.653846   1.461538  0.171615  0.096154
# 1          AJ Hammons    2017  0.000000   0.000000  0.000000  0.000000
# 2        Aaron Brooks    2015  2.411111   6.011111  0.318578  0.855556
# 3        Aaron Brooks    2016  1.436782   3.643678  0.256851  0.563218
# 4        Aaron Brooks    2017  0.352273   0.897727  0.129193  0.125000
# ...               ...     ...       ...        ...       ...       ...
# 3673          Zhou Qi    2017  0.195652   0.826087  0.094913  0.086957
# 3674          Zhou Qi    2018  0.200000   0.200000  0.200000  0.000000
# 3675  Zion Williamson    2019  7.656250  12.781250  0.542250  0.218750
# 3676  Zion Williamson    2020  9.958333  16.527778  0.607681  0.138889
# 3677   Zylan Cheatham    2019  0.812500   1.125000  0.252938  0.000000
#
#           FG3A   FG3_PCT       FTM       FTA  ...       REB       AST  \
# 0     0.230769  0.073712  0.173077  0.384615  ...  1.153846  0.134615
# 1     0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2     2.433333  0.257644  0.688889  0.922222  ...  1.322222  2.233333
# 3     1.563218  0.209759  0.436782  0.540230  ...  0.850575  1.494253
# 4     0.409091  0.075750  0.113636  0.170455  ...  0.193182  0.284091
# ...        ...       ...       ...       ...  ...       ...       ...
# 3673  0.521739  0.043478  0.173913  0.260870  ...  0.608696  0.043478
# 3674  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 3675  0.562500  0.125000  4.250000  6.562500  ...  5.500000  1.843750
# 3676  0.555556  0.118056  5.763889  8.444444  ...  7.194444  3.263889
# 3677  0.125000  0.000000  0.312500  0.500000  ...  1.375000  0.187500
#
#            STL       BLK       TNO        PF        PTS  PLUS_MINUS  \
# 0     0.019231  0.307692  0.269231  0.653846   1.576923    0.038462
# 1     0.000000  0.000000  0.000000  0.000000   0.000000    0.000000
# 2     0.411111  0.122222  1.077778  1.666667   6.366667   -0.022222
# 3     0.298851  0.103448  0.793103  1.160920   3.873563   -0.448276
# 4     0.068182  0.000000  0.136364  0.352273   0.943182   -0.886364
# ...        ...       ...       ...       ...        ...         ...
# 3673  0.043478  0.391304  0.260870  0.434783   0.652174   -1.413043
# 3674  0.000000  0.000000  0.000000  0.000000   0.400000   -0.400000
# 3675  0.687500  0.281250  2.093750  1.656250  19.781250    2.843750
# 3676  1.013889  0.597222  2.652778  2.152778  25.819444    0.402778
# 3677  0.062500  0.125000  0.375000  0.875000   1.937500   -1.500000
#
#           SECONDS   FTSY_PTS
# 0      283.634615   2.298077
# 1        0.000000   0.000000
# 2      841.233333   7.194444
# 3      651.632184   4.666667
# 4      145.420455   0.960227
# ...           ...        ...
# 3673   189.543478   1.217391
# 3674    11.400000   0.400000
# 3675  1456.593750  20.453125
# 3676  1950.597222  29.229167
# 3677   315.000000   3.093750
#
# [3678 rows x 23 columns]

# %%
curry = df.loc[df['PLAYER_NAME'] == 'Stephen Curry']

# %%
#curry_2016 = df.loc[(df['PLAYER_NAME'] == 'Stephen Curry') & (df['SEASON'] == 2016)]

# %%
#curry_2016 = curry_2016[['PLAYER_NAME', 'SEASON', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TNO', 'PF', 'PTS', 'PLUS_MINUS', 'SECONDS', 'FTSY_PTS']]

# %%
curry.set_index('GAME_DATE_EST', inplace = True)

# %%
curry.head()
# Out:
#                 GAME_ID     TEAM_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# GAME_DATE_EST
# 2021-05-21     52000211  1610612744    1610612744       1610612763
# 2021-05-19     52000121  1610612744    1610612747       1610612744
# 2021-05-16     22001070  1610612744    1610612744       1610612763
# 2021-05-14     22001059  1610612744    1610612744       1610612740
# 2021-05-11     22001039  1610612744    1610612744       1610612756
#
#                  PLAYER_NAME  SEASON   FGM   FGA  FG_PCT  FG3M  ...  REB_home  \
# GAME_DATE_EST                                                   ...
# 2021-05-21     Stephen Curry    2020  13.0  28.0   0.464   6.0  ...      48.0
# 2021-05-19     Stephen Curry    2020  12.0  23.0   0.522   6.0  ...      49.0
# 2021-05-16     Stephen Curry    2020  16.0  36.0   0.444   9.0  ...      46.0
# 2021-05-14     Stephen Curry    2020   NaN   NaN     NaN   NaN  ...      46.0
# 2021-05-11     Stephen Curry    2020   7.0  22.0   0.318   1.0  ...      40.0
#
#                PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  \
# GAME_DATE_EST
# 2021-05-21        117.0        0.408        0.846         0.429      22.0
# 2021-05-19        100.0        0.446        0.733         0.441      19.0
# 2021-05-16        101.0        0.435        0.789         0.240      25.0
# 2021-05-14        122.0        0.465        0.679         0.407      21.0
# 2021-05-11        116.0        0.519        0.900         0.432      26.0
#
#                REB_away  HOME_TEAM_WINS  SECONDS  FTSY_PTS
# GAME_DATE_EST
# 2021-05-21         47.0               0     2843      34.5
# 2021-05-19         46.0               1     2437      30.5
# 2021-05-16         39.0               1     2397      42.5
# 2021-05-14         51.0               1        0       NaN
# 2021-05-11         36.0               1     2191      17.0
#
# [5 rows x 40 columns]

# %%
X_train.head()
# Out:
#                 GAME_ID     TEAM_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# GAME_DATE_EST
# 2015-10-05     11500009  1610612744    1610612744       1610612761
# 2015-10-08     11500026  1610612744    1610612757       1610612744
# 2015-10-13     11500056  1610612744    1610612744       1610612743
# 2015-10-15     11500063  1610612744    1610612744       1610612745
# 2015-10-17     11500073  1610612744    1610612747       1610612744
#
#                  PLAYER_NAME  SEASON  FGM   FGA  FG_PCT  FG3M  ...  AST_home  \
# GAME_DATE_EST                                                  ...
# 2015-10-05     Stephen Curry    2015  5.0   7.0   0.714   3.0  ...      29.0
# 2015-10-08     Stephen Curry    2015  6.0  14.0   0.429   6.0  ...      25.0
# 2015-10-13     Stephen Curry    2015  5.0  13.0   0.385   1.0  ...      23.0
# 2015-10-15     Stephen Curry    2015  6.0   7.0   0.857   1.0  ...      31.0
# 2015-10-17     Stephen Curry    2015  7.0  13.0   0.538   5.0  ...      18.0
#
#                REB_home  PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# GAME_DATE_EST
# 2015-10-05         37.0      87.0        0.376        0.826         0.250
# 2015-10-08         48.0     101.0        0.383        0.794         0.375
# 2015-10-13         43.0     114.0        0.495        0.600         0.429
# 2015-10-15         43.0     101.0        0.365        0.828         0.233
# 2015-10-17         36.0      70.0        0.387        0.684         0.450
#
#                AST_away  REB_away  HOME_TEAM_WINS  SECONDS
# GAME_DATE_EST
# 2015-10-05         15.0      48.0               1     1167
# 2015-10-08         20.0      38.0               1     1547
# 2015-10-13         29.0      48.0               0     1586
# 2015-10-15         24.0      55.0               1     1002
# 2015-10-17         14.0      37.0               1     1344
#
# [5 rows x 39 columns]

# %%
y_train
# Out:
# GAME_DATE_EST
# 2015-10-05    14.0
# 2015-10-08    33.5
# 2015-10-13    13.5
# 2015-10-15    30.0
# 2015-10-17    19.0
#               ...
# 2019-03-27    37.5
# 2019-03-29    37.5
# 2019-03-31    38.0
# 2019-04-02    25.5
# 2019-04-04    16.5
# Name: FTSY_PTS, Length: 352, dtype: float64

# %%
curry.dropna(inplace =True)
# Out:
# <ipython-input-217-137760249dc0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curry.dropna(inplace =True)

# %%
curry.loc[curry['SECONDS']== 0]
# Out:
# Empty DataFrame
# Columns: [GAME_ID, TEAM_ID, HOME_TEAM_ID, VISITOR_TEAM_ID, PLAYER_NAME, SEASON, FGM, FGA, FG_PCT, FG3M, FG3A, FG3_PCT, FTM, FTA, FT_PCT, OREB, DREB, REB, AST, STL, BLK, TNO, PF, PTS, PLUS_MINUS, PTS_home, FG_PCT_home, FT_PCT_home, FG3_PCT_home, AST_home, REB_home, PTS_away, FG_PCT_away, FT_PCT_away, FG3_PCT_away, AST_away, REB_away, HOME_TEAM_WINS, SECONDS, FTSY_PTS]
# Index: []
#
# [0 rows x 40 columns]

# %%
curry.sort_index(inplace = True)
# Out:
# <ipython-input-219-f9361c9f5863>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curry.sort_index(inplace = True)

# %%
X= curry.drop(columns = ['FTSY_PTS', 'PLAYER_NAME'])
y= curry['FTSY_PTS']

# %%
X.head()
# Out:
#                 GAME_ID     TEAM_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  SEASON  \
# GAME_DATE_EST
# 2015-10-05     11500009  1610612744    1610612744       1610612761    2015
# 2015-10-08     11500026  1610612744    1610612757       1610612744    2015
# 2015-10-13     11500056  1610612744    1610612744       1610612743    2015
# 2015-10-15     11500063  1610612744    1610612744       1610612745    2015
# 2015-10-17     11500073  1610612744    1610612747       1610612744    2015
#
#                FGM   FGA  FG_PCT  FG3M  FG3A  ...  AST_home  REB_home  \
# GAME_DATE_EST                                 ...
# 2015-10-05     5.0   7.0   0.714   3.0   5.0  ...      29.0      37.0
# 2015-10-08     6.0  14.0   0.429   6.0  11.0  ...      25.0      48.0
# 2015-10-13     5.0  13.0   0.385   1.0   8.0  ...      23.0      43.0
# 2015-10-15     6.0   7.0   0.857   1.0   1.0  ...      31.0      43.0
# 2015-10-17     7.0  13.0   0.538   5.0  10.0  ...      18.0      36.0
#
#                PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  \
# GAME_DATE_EST
# 2015-10-05         87.0        0.376        0.826         0.250      15.0
# 2015-10-08        101.0        0.383        0.794         0.375      20.0
# 2015-10-13        114.0        0.495        0.600         0.429      29.0
# 2015-10-15        101.0        0.365        0.828         0.233      24.0
# 2015-10-17         70.0        0.387        0.684         0.450      14.0
#
#                REB_away  HOME_TEAM_WINS  SECONDS
# GAME_DATE_EST
# 2015-10-05         48.0               1     1167
# 2015-10-08         38.0               1     1547
# 2015-10-13         48.0               0     1586
# 2015-10-15         55.0               1     1002
# 2015-10-17         37.0               1     1344
#
# [5 rows x 38 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= .25, shuffle= False)

# %%
lr= LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_train)
# Out:
# array([14. , 33.5, 13.5, 30. , 19. , 41. , 46.5, 35. , 66.5, 36.5, 34. ,
#        49. , 21.5, 23.5, 36.5, 48. , 26. , 38.5, 45. , 29. , 27.5, 34.5,
#        47. , 34. , 30.5, 41.5, 41.5, 25. , 39. , 39. , 29.5, 30.5, 39.5,
#        28.5, 28.5, 44. , 10. , 32. , 23. , 33.5, 50.5, 26. , 44.5, 26.5,
#        40.5, 45. , 42.5, 59. , 44.5, 30.5, 25. , 14. , 50. , 34. , 42.5,
#        41.5, 31.5, 30.5, 50. , 41.5, 60. , 47. , 32. , 14. , 51.5, 24. ,
#        33. , 34. , 35.5, 36. , 44. , 17. , 33.5, 37.5, 48. , 29. , 37.5,
#        30. , 26. , 49.5, 34.5, 38.5, 23. , 40.5, 52. , 31. ,  3.5, 41. ,
#        38.5, 32.5, 27.5, 25.5, 13.5, 41. , 40.5, 39. ,  9. , 27. , 15.5,
#        38. , 27. , 18.5, 12. , 11.5, 25.5, 23.5, 28. , 19.5, 41.5, 31. ,
#        21. , 22. , 24.5, 22.5, 28.5, 28. , 47.5, 29. , 38. , 38. , 37.5,
#        26. , 17.5, 33. , 43.5, 30.5, 41. , 20.5, 28.5, 28.5, 32.5, 34. ,
#        26. , 15.5, 34.5, 31.5, 18. , 23. , 30. , 22.5, 30. , 17.5, 34.5,
#        19.5, 19.5, 31.5, 40. , 32. , 32.5, 30.5, 29.5, 33. , 24.5, 30. ,
#        27. , 28.5, 51. , 55. , 38.5, 45.5, 17. , 18.5, 41.5,  7.5, 22.5,
#        46.5, 29.5, 16. , 25. , 25.5, 35. , 26.5, 27. , 21.5, 28.5, 36.5,
#        35. , 22. , 32.5, 52. , 31.5, 36.5, 38.5, 29.5, 49. , 29.5, 54.5,
#        31. , 23. , 29. , 25. , 39. , 45. , 30.5, 30. , 19. , 39.5, 40.5,
#        45.5, 30.5, 34. , 42. , 42.5, 40. , 24. , 44. , 11. , 19. , 55. ,
#        20.5, 23. , 33. , 37.5, 37. , 36.5, 27. , 35. , 43. , 34.5, 31.5,
#        15. , 34. , 32.5, 14.5, 36.5, 48.5, 25. , 40. , 25. , 26.5, 35. ,
#        34.5, 41.5, 42.5, 39. , 33.5, 48.5, 38.5, 36.5, 32. , 33. , 14. ,
#        37.5, 41.5, 54.5, 11.5, 25. , 26. , 26.5, 30. , 29. , 31.5, 18. ,
#        60. , 32. , 22.5, 21.5, 30.5, 42. ,  1. , 30.5, 31. , 24. , 16. ,
#        39. , 33. , 19.5, 33.5, 22. , 33. , 36. , 44. , 36.5, 34. , 12. ,
#        44. , 28. , 20. , 27.5, 24. , 43.5, 35. , 28. , 38. , 50.5, 27. ,
#        30.5, 39.5, 42.5, 34.5, 22.5,  9. , 22.5, 30. , 51.5, 25. , 47. ,
#         6.5, 44. , 19.5, 34.5, 19.5, 42. , 13.5, 28.5, 34. , 42. , 28. ,
#        36. , 29. , 35. , 52.5, 32. , 39.5, 33. , 27. , 35.5, 22.5, 34.5,
#        36. ,  8. , 31.5, 27.5, 25. , 34. , 27. , 42.5, 36.5, 20. , 21. ,
#        26. , 28. , 22. , 12. , 28. , 26.5, 29.5, 34. , 38.5, 18.5])

# %%
lr.score(X_test, y_test)
# Out:
# 1.0

# %%
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train.drop(columns= ['GAME_ID','TEAM_ID','HOME_TEAM_ID','VISITOR_TEAM_ID','PLAYER_NAME','SEASON', 'HOME_TEAM_WINS']))
X_test_sc = ss.transform(X_test.drop(columns= ['GAME_ID','TEAM_ID','HOME_TEAM_ID','VISITOR_TEAM_ID','PLAYER_NAME','SEASON', 'HOME_TEAM_WINS']))

# %%
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train, feature_)
X_test_sc = ss.transform(X_test.drop(columns= ['GAME_ID','TEAM_ID','HOME_TEAM_ID','VISITOR_TEAM_ID','PLAYER_NAME','SEASON', 'HOME_TEAM_WINS']))

# %%
feature_names_in_

# %%
train_seq = TimeseriesGenerator(X_train_sc, y_train, length=5, batch_size=64)
test_seq = TimeseriesGenerator(X_test_sc, y_test, length=5, batch_size=64)

# %%
train_seq[0]
# Out:
# (array([[[-1.25355238, -2.38430509,  1.98491538, ..., -1.74750541,
#            0.71307526, -2.61510605],
#          [-0.93548685, -0.93853538, -0.4387634 , ..., -0.91884176,
#           -0.96474888, -1.40985909],
#          [-1.25355238, -1.14507391, -0.81294538, ...,  0.57275282,
#            0.71307526, -1.28616269],
#          [-0.93548685, -2.38430509,  3.20100683, ..., -0.25591083,
#            1.88755217, -3.13843696],
#          [-0.61742132, -1.14507391,  0.48818743, ..., -1.91323814,
#           -1.1325313 , -2.0537147 ]],
#
#         [[-0.93548685, -0.93853538, -0.4387634 , ..., -0.91884176,
#           -0.96474888, -1.40985909],
#          [-1.25355238, -1.14507391, -0.81294538, ...,  0.57275282,
#            0.71307526, -1.28616269],
#          [-0.93548685, -2.38430509,  3.20100683, ..., -0.25591083,
#            1.88755217, -3.13843696],
#          [-0.61742132, -1.14507391,  0.48818743, ..., -1.91323814,
#           -1.1325313 , -2.0537147 ],
#          [ 0.01870974, -0.93853538,  1.38112172, ...,  0.90421828,
#            2.223117  , -0.86749796]],
#
#         [[-1.25355238, -1.14507391, -0.81294538, ...,  0.57275282,
#            0.71307526, -1.28616269],
#          [-0.93548685, -2.38430509,  3.20100683, ..., -0.25591083,
#            1.88755217, -3.13843696],
#          [-0.61742132, -1.14507391,  0.48818743, ..., -1.91323814,
#           -1.1325313 , -2.0537147 ],
#          [ 0.01870974, -0.93853538,  1.38112172, ...,  0.90421828,
#            2.223117  , -0.86749796],
#          [ 1.60903738,  1.53992698,  0.48818743, ..., -0.75310903,
#           -1.80366096,  0.4614454 ]],
#
#         ...,
#
#         [[ 1.60903738,  1.12684992,  0.87087356, ..., -0.0901781 ,
#           -1.97144337,  0.85473652],
#          [ 0.97290632,  1.33338845, -0.00505246, ..., -0.5873763 ,
#            0.37751043,  0.75958544],
#          [-0.93548685,  0.3006958 , -1.53579695, ...,  1.06995101,
#            0.88085768,  0.2077092 ],
#          [ 1.60903738,  1.12684992,  0.87087356, ..., -0.25591083,
#           -0.29361923,  0.78813076],
#          [-1.57161791, -1.35161244, -1.25516046, ..., -0.75310903,
#           -0.29361923, -0.31879342]],
#
#         [[ 0.97290632,  1.33338845, -0.00505246, ..., -0.5873763 ,
#            0.37751043,  0.75958544],
#          [-0.93548685,  0.3006958 , -1.53579695, ...,  1.06995101,
#            0.88085768,  0.2077092 ],
#          [ 1.60903738,  1.12684992,  0.87087356, ..., -0.25591083,
#           -0.29361923,  0.78813076],
#          [-1.57161791, -1.35161244, -1.25516046, ..., -0.75310903,
#           -0.29361923, -0.31879342],
#          [ 1.29097185,  0.92031139,  0.71779911, ..., -0.91884176,
#           -0.79696647, -0.71525623]],
#
#         [[-0.93548685,  0.3006958 , -1.53579695, ...,  1.06995101,
#            0.88085768,  0.2077092 ],
#          [ 1.60903738,  1.12684992,  0.87087356, ..., -0.25591083,
#           -0.29361923,  0.78813076],
#          [-1.57161791, -1.35161244, -1.25516046, ..., -0.75310903,
#           -0.29361923, -0.31879342],
#          [ 1.29097185,  0.92031139,  0.71779911, ..., -0.91884176,
#           -0.79696647, -0.71525623],
#          [ 0.97290632,  1.12684992,  0.16503026, ...,  0.57275282,
#            0.54529285,  0.34092071]]]),
#  array([41. , 46.5, 35. , 66.5, 36.5, 34. , 49. , 21.5, 23.5, 36.5, 48. ,
#         26. , 38.5, 45. , 29. , 27.5, 34.5, 47. , 34. , 30.5, 41.5, 41.5,
#         25. , 39. , 39. , 29.5, 30.5, 39.5, 28.5, 28.5, 44. , 10. , 32. ,
#         23. , 33.5, 50.5, 26. , 44.5, 26.5, 40.5, 45. , 42.5, 59. , 44.5,
#         30.5, 25. , 14. , 50. , 34. , 42.5, 41.5, 31.5, 30.5, 50. , 41.5,
#         60. , 47. , 32. , 14. , 51.5, 24. , 33. , 34. , 35.5]))

# %%
X_train.shape
# Out:
# (352, 39)

# %%
model = Sequential()

#add rnn layer
model.add(GRU(64, input_shape=(5,32), return_sequences=True))
model.add(GRU(16, return_sequences=False))
          
model.add(Dense(16, activation= 'relu'))
model.add(Dropout(.1))
model.add(Dense(8, activation= 'relu'))
model.add(Dropout(.2))
model.add(Dense(1))

model.compile(optimizer='adam', loss= 'mse', metrics= ['mae'])

history=model.fit(train_seq, epochs=30, validation_data= test_seq, verbose=1)
# Out:
# Epoch 1/30
# 6/6 [==============================] - 19s 1s/step - loss: 1125.2570 - mae: 31.8161 - val_loss: 1107.5117 - val_mae: 31.4658
# Epoch 2/30
# 6/6 [==============================] - 0s 77ms/step - loss: 1113.0181 - mae: 31.6218 - val_loss: 1091.7037 - val_mae: 31.2210
# Epoch 3/30
# 6/6 [==============================] - 0s 70ms/step - loss: 1097.4496 - mae: 31.3782 - val_loss: 1070.9926 - val_mae: 30.8944
# Epoch 4/30
# 6/6 [==============================] - 1s 145ms/step - loss: 1076.9138 - mae: 31.0461 - val_loss: 1042.3774 - val_mae: 30.4382
# Epoch 5/30
# 6/6 [==============================] - 0s 68ms/step - loss: 1048.6876 - mae: 30.5719 - val_loss: 1002.3681 - val_mae: 29.7899
# Epoch 6/30
# 6/6 [==============================] - 0s 76ms/step - loss: 1007.7737 - mae: 29.9193 - val_loss: 948.4072 - val_mae: 28.8895
# Epoch 7/30
# 6/6 [==============================] - 0s 79ms/step - loss: 951.2378 - mae: 28.9691 - val_loss: 878.0963 - val_mae: 27.6769
# Epoch 8/30
# 6/6 [==============================] - 0s 65ms/step - loss: 876.8464 - mae: 27.6631 - val_loss: 797.7680 - val_mae: 26.2140
# Epoch 9/30
# 6/6 [==============================] - 0s 69ms/step - loss: 790.5286 - mae: 25.9909 - val_loss: 718.2239 - val_mae: 24.6395
# Epoch 10/30
# 6/6 [==============================] - 0s 70ms/step - loss: 704.8515 - mae: 24.3088 - val_loss: 646.1033 - val_mae: 23.1113
# Epoch 11/30
# 6/6 [==============================] - 1s 143ms/step - loss: 621.8062 - mae: 22.5875 - val_loss: 578.0340 - val_mae: 21.6346
# Epoch 12/30
# 6/6 [==============================] - 1s 131ms/step - loss: 562.3474 - mae: 21.2314 - val_loss: 512.9390 - val_mae: 20.1706
# Epoch 13/30
#        [29.64818 ],
#        [29.647192],
#        [29.649359],
#        [29.661274],
#        [29.647007],
#        [29.651575],
#        [29.627579],
#        [29.665388],
#        [29.672888],
#        [29.668097],
#        [29.645985],
#        [29.657202],
#        [29.648611],
#        [29.656752],
#        [29.668505],
#        [29.67161 ],
#        [29.67077 ],
#        [29.672745],
#        [29.672709],
#        [29.673307],
#        [29.666933],
#        [29.661688],
#        [29.635826],
#        [29.660288],
#        [29.671246],
#        [29.670094],
#        [29.664793],
#        [29.650469],
#        [29.650686],
#        [29.634014],
#        [29.660606],
#        [29.659529],
#        [29.668226],
#        [29.672884],
#        [29.672838],
#        [29.664728],
#        [29.671429],
#        [29.667244],
#        [29.668135],
#        [29.659616],
#        [29.659569],
#        [29.670698],
#        [29.67216 ],
#        [29.671438],
#        [29.674578],
#        [29.617414],
#        [29.614443],
#        [29.652721],
#        [29.662607],
#        [29.650099],
#        [29.665537],
#        [29.671194],
#        [29.673246],
#        [29.673807],
#        [29.6738  ],
#        [29.674562],
#        [29.674665],
#        [29.660658],
#        [29.651503],
#        [29.663225],
#        [29.670683],
#        [29.673103],
#        [29.675228],
#        [29.67519 ],
#        [29.675318],
#        [29.664742],
#        [29.629126],
#        [29.652693],
#        [29.67293 ],
#        [29.674646],
#        [29.67402 ],
#        [29.645126],
#        [29.65903 ],
#        [29.667921],
#        [29.645412],
#        [29.640745],
#        [29.660875],
#        [29.66442 ],
#        [29.640646],
#        [29.640816],
#        [29.650381],
#        [29.662882],
#        [29.667675],
#        [29.670774],
#        [29.671217],
#        [29.6664  ],
#        [29.661201],
#        [29.654781],
#        [29.667446],
#        [29.669447],
#        [29.673859],
#        [29.65735 ],
#        [29.671215],
#        [29.672739],
#        [29.67536 ],
#        [29.677124],
#        [29.669312],
#        [29.669548],
#        [29.669981],
#        [29.67317 ],
#        [29.670122],
#        [29.672926],
#        [29.675018],
#        [29.667639],
#        [29.66548 ],
#        [29.66911 ],
#        [29.670849],
#        [29.67382 ],
#        [29.674658],
#        [29.664253],
#        [29.665245],
#        [29.673738],
#        [29.673872],
#        [29.674028],
#        [29.67242 ],
#        [29.666487],
#        [29.65959 ],
#        [29.671453],
#        [29.673935],
#        [29.676146],
#        [29.67359 ],
#        [29.674906],
#        [29.672873],
#        [29.669277],
#        [29.666445],
#        [29.637512],
#        [29.669764],
#        [29.666386],
#        [29.670425],
#        [29.674541],
#        [29.675982],
#        [29.674608],
#        [29.67545 ],
#        [29.672522],
#        [29.674955],
#        [29.67291 ],
#        [29.6737  ],
#        [29.672832],
#        [29.669233],
#        [29.671385],
#        [29.668587],
#        [29.673822],
#        [29.673319],
#        [29.672462],
#        [29.670252],
#        [29.667353]], dtype=float32)

# %%
model_2 = Sequential()

#add rnn layer
model_2.add(LSTM(64, input_shape=(5,32), return_sequences=True))
model_2.add(LSTM(16, return_sequences=False))
          
model_2.add(Dense(16, activation= 'relu'))
model_2.add(Dropout(.1))
model_2.add(Dense(8, activation= 'relu'))
model_2.add(Dropout(.2))
model_2.add(Dense(1))

model_2.compile(optimizer='adam', loss= 'mse', metrics= ['mae'])

